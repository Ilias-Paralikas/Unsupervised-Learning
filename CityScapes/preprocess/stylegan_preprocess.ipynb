# %%
from preprocess_func import stylegan_preprocess_cityscapes

size = 256

stylegan_preprocess_cityscapes(
    root='../data/original_data',
    output_root='../data/stylegan',
    size=size,
    preprocess_labels=True,
    output_activation='tanh'
)
# Out:
# Found 19998 images
# Generating size: 256x256
# Scaling mode: tanh
# Processing images: 100%|██████████| 19998/19998 [27:47<00:00, 12.00it/s]
# Preprocessing complete!
