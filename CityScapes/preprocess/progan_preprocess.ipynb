# %%
from preprcess_func import preprocess_cityscapes

# %%
sizes = [4,8,16,32,64,128,256]

preprocess_cityscapes(
    root='../data/original_data',
    output_root='../data/progan',
    sizes=sizes,
    preprocess_labels=True,
    output_activation='tanh'
)
# Out:
# Found 19998 images
# Generating sizes: [(4, 4), (8, 8), (16, 16), (32, 32), (64, 64), (128, 128), (256, 256)]
# Scaling mode: tanh
# Processing images: 100%|██████████| 19998/19998 [42:44<00:00,  7.80it/s]
# Preprocessing complete!
